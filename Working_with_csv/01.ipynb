# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Opening_cvs files

# %%
df = pd.read_csv('aug_train.csv')
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# #Sep Parameter

# %%
#yahan ek tsc file load karengy per wo shi se data fetch nhi ker paegi tw hum function k ander sep use karengy q k tsv mei data tab se seperated hota tw 
pd.read_csv('movie_titles_metadata.tsv' , sep='\t')
#Error : columns ka naam nhi hai first row he column bangya hai tw hum khud se ek ;ist pass ker sakty hain
# Out:
#        m0  10 things i hate about you  1999  6.9   62847  \
# 0      m1  1492: conquest of paradise  1992  6.2   10421
# 1      m2                  15 minutes  2001  6.1   25854
# 2      m3       2001: a space odyssey  1968  8.4  163227
# 3      m4                     48 hrs.  1982  6.9   22289
# 4      m5        the sum of all fears  1966  6.8  198939
# ..    ...                         ...   ...  ...     ...
# 611  m612                    watchmen  2009  7.8  135229
# 612  m613                         xxx  2002  5.6   53505
# 613  m614                       x-men  2000  7.4  122149
# 614  m615          young frankenstein  1974  8.0   57618
# 615  m616                   zulu dawn  1979  6.4    1911
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# 3       ['action' 'comedy' 'crime' 'drama' 'thriller']
# ...

# %%
#Error : columns ka naam nhi hai first row he column bangya hai tw hum khud se ek ;ist pass ker sakty hain
pd.read_csv('movie_titles_metadata.tsv' , sep='\t', names=['S_no', 'Name', 'Year_of_Release', 'Rating', 'Votes', 'Genre'])
# Out:
#      S_no                        Name  Year_of_Release  Rating   Votes  \
# 0      m0  10 things i hate about you             1999     6.9   62847
# 1      m1  1492: conquest of paradise             1992     6.2   10421
# 2      m2                  15 minutes             2001     6.1   25854
# 3      m3       2001: a space odyssey             1968     8.4  163227
# 4      m4                     48 hrs.             1982     6.9   22289
# ..    ...                         ...              ...     ...     ...
# 612  m612                    watchmen             2009     7.8  135229
# 613  m613                         xxx             2002     5.6   53505
# 614  m614                       x-men             2000     7.4  122149
# 615  m615          young frankenstein             1974     8.0   57618
# 616  m616                   zulu dawn             1979     6.4    1911
#
#                                                  Genre
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# Index_Col parameter

# %%
pd.read_csv('aug_train.csv')
# Out:
#      enrollee_id      city  city_development_index gender  \
# 0           8949  city_103                   0.920   Male
# 1          29725   city_40                   0.776   Male
# 2          11561   city_21                   0.624    NaN
# 3          33241  city_115                   0.789    NaN
# 4            666  city_162                   0.767   Male
# ..           ...       ...                     ...    ...
# 152        32036   city_16                   0.898   Male
# 153         7386  city_173                   0.878   Male
# 154        31398  city_103                   0.920   Male
# 155        24576  city_103                   0.920   Male
# 156         5756   city_65                   0.802   Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# 2     No relevent experience    Full time course        Graduate
# ...

# %%
# hum column ko index column bana sakty hai 
pd.read_csv('aug_train.csv', index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 32036         city_16                   0.898   Male   No relevent experience
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
#
# ...

# %% [markdown]
# Header Parameter

# %%
pd.read_csv('test.csv')
# Out:
#      Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0             0  enrollee_id       city  city_development_index     gender
# 1             1        29725    city_40                   0.776       Male
# 2             2        11561    city_21                   0.624        NaN
# 3             3        33241   city_115                   0.789        NaN
# 4             4          666   city_162                   0.767       Male
# ..          ...          ...        ...                     ...        ...
# 152         152        32036    city_16                   0.898       Male
# 153         153         7386   city_173                   0.878       Male
# 154         154        31398   city_103                    0.92       Male
# 155         155        24576   city_103                    0.92       Male
# 156         156         5756    city_65                   0.802       Male
#
# ...

# %%
# unnamed column
pd.read_csv('test.csv', header=1) # ab firt row jjo hai columns ka naam banjaegi
# Out:
#        0  enrollee_id      city  city_development_index gender  \
# 0      1        29725   city_40                   0.776   Male
# 1      2        11561   city_21                   0.624    NaN
# 2      3        33241  city_115                   0.789    NaN
# 3      4          666  city_162                   0.767   Male
# 4      5         7297   city_40                   0.817   Male
# ..   ...          ...       ...                     ...    ...
# 151  152        32036   city_16                   0.898   Male
# 152  153         7386  city_173                   0.878   Male
# 153  154        31398  city_103                   0.920   Male
# 154  155        24576  city_103                   0.920   Male
# 155  156         5756   city_65                   0.802   Male
#
#          relevent_experience enrolled_university education_level  \
# 0     No relevent experience       no_enrollment        Graduate
# 1     No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# use_col Parameter

# %%
pd.read_csv('aug_train.csv')
# Out:
#      enrollee_id      city  city_development_index gender  \
# 0           8949  city_103                   0.920   Male
# 1          29725   city_40                   0.776   Male
# 2          11561   city_21                   0.624    NaN
# 3          33241  city_115                   0.789    NaN
# 4            666  city_162                   0.767   Male
# ..           ...       ...                     ...    ...
# 152        32036   city_16                   0.898   Male
# 153         7386  city_173                   0.878   Male
# 154        31398  city_103                   0.920   Male
# 155        24576  city_103                   0.920   Male
# 156         5756   city_65                   0.802   Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# 2     No relevent experience    Full time course        Graduate
# ...

# %%
#selected columns only fetch
pd.read_csv('aug_train.csv', usecols=['enrollee_id', 'gender', 'education_level'])
# Out:
#      enrollee_id gender education_level
# 0           8949   Male        Graduate
# 1          29725   Male        Graduate
# 2          11561    NaN        Graduate
# 3          33241    NaN        Graduate
# 4            666   Male         Masters
# ..           ...    ...             ...
# 152        32036   Male        Graduate
# 153         7386   Male        Graduate
# 154        31398   Male        Graduate
# 155        24576   Male        Graduate
# 156         5756   Male     High School
#
# [157 rows x 3 columns]

# %% [markdown]
# Skip_rows/n_rows

# %%
# skip row mein particular row ko remove kersakty ho 
pd.read_csv('aug_train.csv', skiprows=[0,1])
# zarori nhi line wise nhumber do
# Out:
#      29725   city_40  0.776   Male   No relevent experience     no_enrollment  \
# 0    11561   city_21  0.624    NaN   No relevent experience  Full time course
# 1    33241  city_115  0.789    NaN   No relevent experience               NaN
# 2      666  city_162  0.767   Male  Has relevent experience     no_enrollment
# 3     7297   city_40  0.817   Male  Has relevent experience  Full time course
# 4     1740    city_7  0.541  Other  Has relevent experience     no_enrollment
# ..     ...       ...    ...    ...                      ...               ...
# 150  32036   city_16  0.898   Male   No relevent experience     no_enrollment
# 151   7386  city_173  0.878   Male   No relevent experience     no_enrollment
# 152  31398  city_103  0.920   Male  Has relevent experience     no_enrollment
# 153  24576  city_103  0.920   Male  Has relevent experience     no_enrollment
# 154   5756   city_65  0.802   Male  Has relevent experience     no_enrollment
#
# ...

# %%
pd.read_csv('aug_train.csv', nrows=100)
# ye restrict kerdeta hai rows ko jitni apko chahyeye ho
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# ..          ...       ...                     ...     ...
# 95        23211  city_162                   0.642   Other
# 96         1367   city_97                   0.527  Female
# 97        22251   city_28                   0.610    Male
# 98         9598   city_75                   0.540  Female
# 99        21182   city_97                   0.517    Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# dtypes parameters

# %%
pd.read_csv('aug_train.csv' dtype={'traget':int})
# Out:
#      enrollee_id      city  city_development_index gender  \
# 0           8949  city_103                   0.920   Male
# 1          29725   city_40                   0.776   Male
# 2          11561   city_21                   0.624    NaN
# 3          33241  city_115                   0.789    NaN
# 4            666  city_162                   0.767   Male
# ..           ...       ...                     ...    ...
# 152        32036   city_16                   0.898   Male
# 153         7386  city_173                   0.878   Male
# 154        31398  city_103                   0.920   Male
# 155        24576  city_103                   0.920   Male
# 156         5756   city_65                   0.802   Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# 2     No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# Handling Dates

# %%
# Dates ko string se float ya number mein convert
#hamry pass abhi dates wala column nhi per mein uska code likh raha hon 
pd.read_csv('aug_train.csv', parse_date=['date'])
